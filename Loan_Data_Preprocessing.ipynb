# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("../Downloads/loan_data.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df["Gender"] = df["Gender"].fillna("NA")

# %%
df[["Married", "Dependents", "Self_Employed"]] = df[["Married", "Dependents", "Self_Employed"]].fillna("NA")

# %%
df["Loan_Amount_Term"] = df["Loan_Amount_Term"].fillna(df["Loan_Amount_Term"].mode())

# %%
df["LoanAmount"] = df["LoanAmount"].fillna(df["LoanAmount"].mean())

# %%
df["Credit_History"] = df["Credit_History"].fillna(0)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# #### Labeling

# %%
le = LabelEncoder()
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
#df["Property_Area"]=df["Property_Area"].apply(le.fit_transform)
df[["Property_Area"]]=le.fit_transform(df[["Property_Area"]])
df[["Property_Area"]]
# Out:
# C:\Users\sarth\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
#      Property_Area
# 0                2
# 1                0
# 2                2
# 3                2
# 4                2
# ..             ...
# 609              0
# 610              0
# 611              2
# 612              2
# 613              1
#
# [614 rows x 1 columns]

# %%
df[["Loan_Status"]]=le.fit_transform(df[["Loan_Status"]])
df[["Loan_Status"]]
# Out:
# C:\Users\sarth\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
#      Loan_Status
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1
# ..           ...
# 609            1
# 610            1
# 611            1
# 612            1
# 613            0
#
# [614 rows x 1 columns]

# %% [markdown]
# ### Scaling

# %%
mm=MinMaxScaler()
tdf = df[["ApplicantIncome","CoapplicantIncome","LoanAmount"]]
mdf=mm.fit_transform(tdf)
mdf=pd.DataFrame(mdf,columns=tdf.columns)
mdf
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount
# 0           0.070489           0.000000    0.198860
# 1           0.054830           0.036192    0.172214
# 2           0.035250           0.000000    0.082489
# 3           0.030093           0.056592    0.160637
# 4           0.072356           0.000000    0.191027
# ..               ...                ...         ...
# 609         0.034014           0.000000    0.089725
# 610         0.048930           0.000000    0.044863
# 611         0.097984           0.005760    0.353111
# 612         0.091936           0.000000    0.257598
# 613         0.054830           0.000000    0.179450
#
# [614 rows x 3 columns]
